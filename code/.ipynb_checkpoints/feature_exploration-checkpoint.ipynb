# %%
import MDP_function as mf
import numpy as np 
import pandas as pd

# %%
data_file = "MDP_Original_data2.csv"
original_data = pd.read_csv(data_file)
original_data.describe()
# Out:
#            session       reward  Interaction    hintCount     TotalTime  \
# count  7168.000000  7168.000000  7168.000000  7168.000000   7168.000000
# mean      2.825893    -0.365731    57.369420     1.238281    319.926976
# std       2.660836    34.608128    90.785968     4.150359    521.219816
# min       1.000000  -400.000000     2.000000     0.000000      0.043000
# 25%       1.000000     0.000000    11.000000     0.000000     60.468500
# 50%       2.000000     0.000000    28.000000     0.000000    169.458000
# 75%       4.000000     0.000000    68.000000     0.000000    318.528594
# max      23.000000   200.000000  1945.000000    86.000000  10279.619000
#
#         TotalPSTime  TotalWETime  avgstepTime  avgstepTimePS  \
# count   7168.000000  7168.000000  7168.000000    7168.000000
# mean     295.182141    16.530526     5.537452       5.735026
# std      530.406424    41.548154     3.829625       2.859971
# min        0.000000     0.000000     0.021500       0.000000
# 25%        0.000000     0.000000     3.150274       4.485834
# 50%      144.681000     0.000000     5.264116       5.730519
# 75%      308.122250     8.892500     6.747486       5.730519
# max    10279.619000   507.912000    59.729500      60.000000
#
#        stepTimeDeviation           ...            cumul_NextStepClickCountWE  \
# count        7168.000000           ...                           7168.000000
# mean           10.268990           ...                              7.513811
# std             3.717992           ...                              4.590085
# min             0.059397           ...                              0.000000
# 25%             8.347408           ...                              5.000000
# 50%            10.266256           ...                              8.000000
# 75%            12.201701           ...                             10.000000
# max            42.426407           ...                             31.000000
#
#        cumul_PreviousStepClickCountWE  cumul_deletedApp  CurrPro_NumProbRule  \
# count                     7168.000000       7168.000000          7168.000000
# mean                         0.588449          2.844866             4.629464
# std                          1.868344          6.437510             1.192499
# min                          0.000000          0.000000             2.000000
# 25%                          0.000000          0.000000             4.000000
# 50%                          0.000000          0.000000             4.000000
# 75%                          0.000000          3.000000             5.000000
# max                         27.000000        109.000000             8.000000
#
#        CurrPro_avgProbTime  CurrPro_avgProbTimePS  \
# count          7168.000000            7168.000000
# mean            279.949603             257.392188
# std             169.876367             167.132534
# min              28.337368              28.337368
# 25%             146.481187             125.796686
# 50%             224.548622             213.699039
# 75%             375.310788             361.420962
# max             705.756679             705.756679
#
#        CurrPro_avgProbTimeDeviationPS  CurrPro_avgProbTimeWE  \
# count                     7168.000000            7168.000000
# mean                       453.690448              16.049245
# std                        234.409036              15.696234
# min                         72.712209               0.000000
# 25%                        263.064301               0.000000
# 50%                        419.323792              12.346511
# 75%                        570.055935              27.746320
# max                       1017.360329              48.043621
#
#        CurrPro_avgProbTimeDeviationWE  CurrPro_medianProbTime
# count                     7168.000000             7168.000000
# mean                        28.399292              120.164800
# std                         26.001224              115.132244
# min                          0.000000                0.126000
# 25%                          0.000000               63.200500
# 50%                         32.380211               81.495000
# 75%                         48.647872              148.718000
# max                         85.893332              506.664000
#
# [8 rows x 126 columns]

# %%
# original_data.columns.tolist()

# %%
len(original_data.columns.tolist())
# Out:
# 130

# %%
original_features = original_data.loc[:, 'reward':'CurrPro_medianProbTime']
original_features.describe()
# Out:
#             reward  Interaction    hintCount     TotalTime   TotalPSTime  \
# count  7168.000000  7168.000000  7168.000000   7168.000000   7168.000000
# mean     -0.365731    57.369420     1.238281    319.926976    295.182141
# std      34.608128    90.785968     4.150359    521.219816    530.406424
# min    -400.000000     2.000000     0.000000      0.043000      0.000000
# 25%       0.000000    11.000000     0.000000     60.468500      0.000000
# 50%       0.000000    28.000000     0.000000    169.458000    144.681000
# 75%       0.000000    68.000000     0.000000    318.528594    308.122250
# max     200.000000  1945.000000    86.000000  10279.619000  10279.619000
#
#        TotalWETime  avgstepTime  avgstepTimePS  stepTimeDeviation  \
# count  7168.000000  7168.000000    7168.000000        7168.000000
# mean     16.530526     5.537452       5.735026          10.268990
# std      41.548154     3.829625       2.859971           3.717992
# min       0.000000     0.021500       0.000000           0.059397
# 25%       0.000000     3.150274       4.485834           8.347408
# 50%       0.000000     5.264116       5.730519          10.266256
# 75%       8.892500     6.747486       5.730519          12.201701
# max     507.912000    59.729500      60.000000          42.426407
#
#        symbolicRepresentationCount           ...            \
# count                  7168.000000           ...
# mean                      0.956473           ...
# std                       0.243349           ...
# min                       0.000000           ...
# 25%                       1.000000           ...
# 50%                       1.000000           ...
# 75%                       1.000000           ...
# max                       2.000000           ...
#
#        cumul_NextStepClickCountWE  cumul_PreviousStepClickCountWE  \
# count                 7168.000000                     7168.000000
# mean                     7.513811                        0.588449
# std                      4.590085                        1.868344
# min                      0.000000                        0.000000
# 25%                      5.000000                        0.000000
# 50%                      8.000000                        0.000000
# 75%                     10.000000                        0.000000
# max                     31.000000                       27.000000
#
#        cumul_deletedApp  CurrPro_NumProbRule  CurrPro_avgProbTime  \
# count       7168.000000          7168.000000          7168.000000
# mean           2.844866             4.629464           279.949603
# std            6.437510             1.192499           169.876367
# min            0.000000             2.000000            28.337368
# 25%            0.000000             4.000000           146.481187
# 50%            0.000000             4.000000           224.548622
# 75%            3.000000             5.000000           375.310788
# max          109.000000             8.000000           705.756679
#
#        CurrPro_avgProbTimePS  CurrPro_avgProbTimeDeviationPS  \
# count            7168.000000                     7168.000000
# mean              257.392188                      453.690448
# std               167.132534                      234.409036
# min                28.337368                       72.712209
# 25%               125.796686                      263.064301
# 50%               213.699039                      419.323792
# 75%               361.420962                      570.055935
# max               705.756679                     1017.360329
#
#        CurrPro_avgProbTimeWE  CurrPro_avgProbTimeDeviationWE  \
# count            7168.000000                     7168.000000
# mean               16.049245                       28.399292
# std                15.696234                       26.001224
# min                 0.000000                        0.000000
# 25%                 0.000000                        0.000000
# 50%                12.346511                       32.380211
# 75%                27.746320                       48.647872
# max                48.043621                       85.893332
#
#        CurrPro_medianProbTime
# count             7168.000000
# mean               120.164800
# std                115.132244
# min                  0.126000
# 25%                 63.200500
# 50%                 81.495000
# 75%                148.718000
# max                506.664000
#
# [8 rows x 125 columns]

# %%
import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline
# f, ax = plt.subplots(figsize=(48, 48))
corr = original_features.corr()
# sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
#             square=True, ax=ax)

# %%
result = pd.qcut(original_data['Level'], 4, labels=[0,1,2,3])
result.unique()
# Out:
# [0, 1, 2, 3]
# Categories (4, int64): [0 < 1 < 2 < 3]

# %%
# select all features from the original dataset and get features names as feature space indexes
feature_data = original_data.loc[:, 'Interaction':'CurrPro_medianProbTime']
feature_space = feature_data.columns.tolist()

# %%
#pd.DataFrame.hist(original_data, column=feature_space)
# sns.pairplot(feature_data)

# %%
selected_feature_file = "Training_data.csv"
selected_feature_data = pd.read_csv(selected_feature_file)
selected_feature_data.describe()
# Out:
#            session       reward  difficultProblemCountSolved  \
# count  7168.000000  7168.000000                  7168.000000
# mean      2.825893    -0.365731                     0.294364
# std       2.660836    34.608128                     0.455788
# min       1.000000  -400.000000                     0.000000
# 25%       1.000000     0.000000                     0.000000
# 50%       2.000000     0.000000                     0.000000
# 75%       4.000000     0.000000                     1.000000
# max      23.000000   200.000000                     1.000000
#
#        cumul_MorphCount  CurrPro_avgProbTimeDeviationPS  cumul_FDActionCount  \
# count       7168.000000                     7168.000000          7168.000000
# mean           0.484933                        0.456055             0.499163
# std            0.499808                        0.498100             0.500034
# min            0.000000                        0.000000             0.000000
# 25%            0.000000                        0.000000             0.000000
# 50%            0.000000                        0.000000             0.000000
# 75%            1.000000                        1.000000             1.000000
# max            1.000000                        1.000000             1.000000
#
#        ruleScoreEQUIV  cumul_TotalWETime  cumul_symbolicRepresentationCount  \
# count     7168.000000        7168.000000                        7168.000000
# mean         0.494978           0.499302                           0.418806
# std          0.500010           0.500034                           0.493398
# min          0.000000           0.000000                           0.000000
# 25%          0.000000           0.000000                           0.000000
# 50%          0.000000           0.000000                           0.000000
# 75%          1.000000           1.000000                           1.000000
# max          1.000000           1.000000                           1.000000
#
#        cumul_AppRatio
# count     7168.000000
# mean         0.499302
# std          0.500034
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000

# %%
selected_features = selected_feature_data.loc[:, 'reward':]
corr = selected_features.corr()
f, ax = plt.subplots()
# sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
#             square=True, ax=ax)
sns.heatmap(corr, square=True)

# %%
# f, ax = plt.subplots(figsize=(48,48))
sns.pairplot(selected_features)

# %%
sns.heatmap(corr, annot=True, fmt=".2f", linewidths=.5)
