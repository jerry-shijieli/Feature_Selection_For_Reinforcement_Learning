# %%
import MDP_function as mf
import numpy as np 
import pandas as pd
import matplotlib.pylab as plt
import scipy.stats as stats
import random as rnd
import collections
import progressbar as pgb
import pickle
import time
import sys
import os
# %matplotlib inline
pd.options.mode.chained_assignment = None # disable unnecessary warning

# %%
# read in all original data set
data_file = "MDP_Original_data2.csv"
original_data = pd.read_csv(data_file)

# %%
# select all features from the original dataset and get features names as feature space indexes
feature_data = original_data.loc[:, 'Interaction':'CurrPro_medianProbTime']
feature_space = feature_data.columns.tolist()

# %%
# initialize parameters and data structures for correlation-based feature selection algorithm
MAX_NUM_OF_FEATURES = 8
ECR_list_of_single_feature = list()
optimal_feature_set = list()
max_total_ECR = 0
initial_num_of_features = 1
extra_num_of_features = 1

# %%
# discretization feature values by median
all_data_discretized = original_data.loc[:, "student":"reward"]
print ">>> Feature discretization ... "
bar = pgb.ProgressBar()
for ft in bar(feature_space):
    ft_data = original_data.loc[:, ft]
    all_data_discretized[ft] = mf.feature_discretization_by_median(ft_data)
del original_data
# Out:
# >>> Feature discretization ...
# 100% |########################################################################|

# %%
# initialization to find the best feature with max ECR
feature_ECR_rank_file = "feature_ECR_rank.pkl"
if os.path.exists(feature_ECR_rank_file):
    print ">>> Load ECR for each individual feature (may take a while)..."
    with open(feature_ECR_rank_file, "rb") as fin:
        ECR_list_of_single_feature = pickle.load(fin)
    print "\tSuccessful! Continue ..."
else:
    print ">>> Compute ECR for each individual feature (may take a while)..."
    bar = pgb.ProgressBar()
    for ft in bar(feature_space):
        ECR_list_of_single_feature.append([ft, mf.compute_ECR(all_data_discretized, [ft])])
    with open(feature_ECR_rank_file, "wb") as fout:
        pickle.dump(ECR_list_of_single_feature, fout)
# Out:
# >>> Load ECR for each individual feature (may take a while)...
# 	Successful! Continue ...

# %%
# initialize the optimal feature set with feature of highest ECR
ECR_list_of_single_feature = sorted(ECR_list_of_single_feature, key=lambda x: x[1], reverse=True) # sort feature by ECR
ECR_dict_of_single_feature = dict(ECR_list_of_single_feature)
feature_space = map(lambda x: x[0], ECR_list_of_single_feature) # update feature space by ECR order
optimal_feature_set.extend(map(lambda x: x[0], ECR_list_of_single_feature[:initial_num_of_features])) # select top 7 ECR features
start_time = time.time() # record start time to measure searching time
print "* Initial optimal feature selection is "
print optimal_feature_set
print "* Initial ECR is "
max_total_ECR = mf.compute_ECR(all_data_discretized, optimal_feature_set)
print str(max_total_ECR)
# Out:
# * Initial optimal feature selection is
# ['probIndexinLevel']
# * Initial ECR is
# 19.3657551551

# %%
# feature selection iterations
valid_optimal_feature_set = list() # record the 8 optimal features.
valid_max_total_ECR = max_total_ECR if (len(optimal_feature_set)<=MAX_NUM_OF_FEATURES) else 0
prev_optimal_feature_set = list()
while (len(optimal_feature_set) < MAX_NUM_OF_FEATURES+extra_num_of_features):
    if (set(prev_optimal_feature_set) == set(optimal_feature_set)):
        break # if no change in optimal set, then end searching loop
    else:
        prev_optimal_feature_set = list(optimal_feature_set)
    print "\n********* Search next feature on level <"+str(len(optimal_feature_set))+"> *********"
    remain_feature_space = list([ft for ft in feature_space if ft not in optimal_feature_set])# features not in optimal feature set
    # feature selection heuristics
    print ">>> Select candidate feature set ..."
    topK = len(remain_feature_space)/2+int(0.01*np.exp(len(optimal_feature_set))) # dynamically choose top-K candidate features based on feature similarity metrics
    topK = min([topK, len(remain_feature_space)]) # check if topK is within capacity of candidate feature set
    count_features = 0
    #rnd.shuffle(remain_feature_space)
    top_features = remain_feature_space[:topK]
    # select optimal feature from candidate set based on ECR value
    ECR_list = list() # ECR values of optimal feature set with new candidate feature
    for ft in top_features:
        selected_feature = list(optimal_feature_set)
        selected_feature.append(ft) # combine candidate feature to optimal feature set
        ECR_with_ft_added = mf.compute_ECR(all_data_discretized, selected_feature)
        print "* Candidate feature: "+ ft +" --> ECR value: "+ str(ECR_with_ft_added)
        if (ECR_with_ft_added >= valid_max_total_ECR):
            print "\tQualified candidate feature added +"
            ECR_list.append([ft, ECR_with_ft_added])
        else:
            print "\tUnqualified candidate feature skipped ~"
    if (not ECR_list): # if no new qualified candidate feature, keep searching
        continue
    else:
        print ">>> test subset ECR ... "
        best_candidate_ft_set = list()
        bar = pgb.ProgressBar()
        for i in bar(range(len(ECR_list))):
            if (ECR_list[i][1] >= valid_max_total_ECR):
                candidate_ft_set = optimal_feature_set+[ECR_list[i][0]]
                max_total_ECR = ECR_list[i][1]
                is_subset_better = True
                best_candidate_ft_set = list(candidate_ft_set)
                subset_size = len(best_candidate_ft_set)
                while (subset_size>1 and is_subset_better):
                    choices = range(subset_size-1)
                    ECR_sublist = map(lambda f_id: mf.compute_ECR(all_data_discretized, best_candidate_ft_set[:f_id]+best_candidate_ft_set[f_id+1:]), choices)
                    max_ECR_in_subset = max(ECR_sublist)
                    if (subset_size-1<=MAX_NUM_OF_FEATURES and max_ECR_in_subset >= valid_max_total_ECR): # choose subset with ECR no less than highest overall ECR
                        print "!!!Better optimal feature subset is discovered!!!"
                        ft_index_of_max_subset_ECR = ECR_sublist.index(max_ECR_in_subset)
                        ft_removed = best_candidate_ft_set.pop(ft_index_of_max_subset_ECR)
                        max_total_ECR = max_ECR_in_subset
                        subset_size = len(best_candidate_ft_set)
                        if (subset_size <= MAX_NUM_OF_FEATURES):
                            valid_max_total_ECR = max_total_ECR
                            valid_optimal_feature_set = list(best_candidate_ft_set)
                        print "\tRemove feature "+str(ft_removed) 
                    elif (subset_size>MAX_NUM_OF_FEATURES+1 and max_ECR_in_subset >= max_total_ECR):
                        print "!!!Better optimal feature subset is discovered!!!"
                        ft_index_of_max_subset_ECR = ECR_sublist.index(max_ECR_in_subset)
                        ft_removed = best_candidate_ft_set.pop(ft_index_of_max_subset_ECR)
                        max_total_ECR = max_ECR_in_subset
                        subset_size = len(best_candidate_ft_set)
                        print "\tRemove feature "+str(ft_removed) 
                    else:
                        is_subset_better = False
        optimal_feature_set = list(best_candidate_ft_set)
        if (len(optimal_feature_set) <= MAX_NUM_OF_FEATURES) and (max_total_ECR >= valid_max_total_ECR):
            valid_optimal_feature_set = list(optimal_feature_set)
            valid_max_total_ECR = max_total_ECR
    # keep record of the highest ECR and its optimal feature set so far
    print "Max ECR touched so far: "+str(max_total_ECR)+" with "+str(len(optimal_feature_set))+" optimal features as:"
    print optimal_feature_set
    print "Highest valid ECR so far: "+str(valid_max_total_ECR)+" with "+str(len(valid_optimal_feature_set))+" optimal features as:"
    print valid_optimal_feature_set
# Out:
# ********* Search next feature on level <1> *********
# >>> Select candidate feature set ...
# * Candidate feature: cumul_probIndexinLevel --> ECR value: 19.3657551551
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimeWE --> ECR value: 34.5608593787
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimeDeviationWE --> ECR value: 31.0209214718
# 	Qualified candidate feature added +
# * Candidate feature: difficultProblemCountSolved --> ECR value: 36.0716146758
# 	Qualified candidate feature added +
# * Candidate feature: cumul_NonPSelements --> ECR value: 19.991206373
# 	Qualified candidate feature added +
# * Candidate feature: cumul_DirectProofActionCount --> ECR value: 20.0366719515
# 	Qualified candidate feature added +
# * Candidate feature: difficultProblemCountWE --> ECR value: 18.8759002972
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_Interaction --> ECR value: 19.8173190459
# 	Qualified candidate feature added +
# * Candidate feature: cumul_actionCount --> ECR value: 19.7453255393
# 	Qualified candidate feature added +
# * Candidate feature: cumul_FDActionCount --> ECR value: 19.8749181807
# 	Qualified candidate feature added +
# * Candidate feature: cumul_WrongApp --> ECR value: 19.8447989019
# 	Qualified candidate feature added +
# * Candidate feature: cumul_symbolicRepresentationCount --> ECR value: 24.1997674503
# 	Qualified candidate feature added +
# * Candidate feature: cumul_WrongSyntaxApp --> ECR value: 19.7689773468
# 	Qualified candidate feature added +
# * Candidate feature: cumul_InterfaceErrorCount --> ECR value: 19.4447075685
# 	Qualified candidate feature added +
# * Candidate feature: cumul_TotalPSTime --> ECR value: 19.8343876656
# 	Qualified candidate feature added +
# * Candidate feature: cumul_AppCount --> ECR value: 20.0142530821
# 	Qualified candidate feature added +
# * Candidate feature: cumul_easyProblemCountSolved --> ECR value: 23.3318427607
# 	Qualified candidate feature added +
# * Candidate feature: cumul_WrongSemanticsApp --> ECR value: 19.525970491
# 	Qualified candidate feature added +
# * Candidate feature: cumul_PrepCount --> ECR value: 20.0722909055
# 	Qualified candidate feature added +
# * Candidate feature: cumul_TotalTime --> ECR value: 19.489064979
# 	Qualified candidate feature added +
# * Candidate feature: cumul_UseCount --> ECR value: 19.3941629875
# 	Qualified candidate feature added +
# * Candidate feature: cumul_MorphCount --> ECR value: 20.2605741606
# 	Qualified candidate feature added +
# * Candidate feature: cumul_RuleTypesCount --> ECR value: 21.2538234491
# 	Qualified candidate feature added +
# * Candidate feature: probIndexPSinLevel --> ECR value: 18.8196345563
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_hintCount --> ECR value: 18.865685453
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_hintRatio --> ECR value: 18.865685453
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_OptionalCount --> ECR value: 20.9534157257
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_NumProbRule --> ECR value: 19.2168053609
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_avgProbTimeDeviationPS --> ECR value: 25.7993128898
# 	Qualified candidate feature added +
# * Candidate feature: SeenWEinLevel --> ECR value: 18.6561699207
# 	Unqualified candidate feature skipped ~
# * Candidate feature: NextStepClickCountWE --> ECR value: 19.6139274711
# 	Qualified candidate feature added +
# * Candidate feature: cumul_RightApp --> ECR value: 19.2021791939
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalWETime --> ECR value: 19.7818918705
# 	Qualified candidate feature added +
# * Candidate feature: cumul_deletedApp --> ECR value: 19.880038544
# 	Qualified candidate feature added +
# * Candidate feature: cumul_NextStepClickCountWE --> ECR value: 24.3906173896
# 	Qualified candidate feature added +
# * Candidate feature: WrongApp --> ECR value: 19.487585507
# 	Qualified candidate feature added +
# * Candidate feature: WrongSyntaxApp --> ECR value: 19.4920798352
# 	Qualified candidate feature added +
# * Candidate feature: cumul_AppRatio --> ECR value: 19.9101693696
# 	Qualified candidate feature added +
# * Candidate feature: cumul_BlankRatio --> ECR value: 19.8488156784
# 	Qualified candidate feature added +
# * Candidate feature: cumul_englishSymbolicSwitchCount --> ECR value: 18.739387239
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreCD --> ECR value: 20.0196560941
# 	Qualified candidate feature added +
# * Candidate feature: easyProblemCountSolved --> ECR value: 23.1479210562
# 	Qualified candidate feature added +
# * Candidate feature: ruleScoreASSOC --> ECR value: 19.5564244609
# 	Qualified candidate feature added +
# * Candidate feature: cumul_avgstepTimeWE --> ECR value: 23.8766551806
# 	Qualified candidate feature added +
# * Candidate feature: WrongSemanticsApp --> ECR value: 20.5768663214
# 	Qualified candidate feature added +
# * Candidate feature: ruleScoreDIST --> ECR value: 19.3085714359
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalPSTime --> ECR value: 20.6799955568
# 	Qualified candidate feature added +
# * Candidate feature: cumul_HoverHintCount --> ECR value: 18.3840647589
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_SystemInfoHintCount --> ECR value: 18.8876153973
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreEXP --> ECR value: 19.9680580858
# 	Qualified candidate feature added +
# * Candidate feature: FDActionCount --> ECR value: 20.2687423888
# 	Qualified candidate feature added +
# * Candidate feature: actionCount --> ECR value: 20.2809650414
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimePS --> ECR value: 19.6410047664
# 	Qualified candidate feature added +
# * Candidate feature: ruleScoreCOM --> ECR value: 19.7419837519
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_medianProbTime --> ECR value: 19.3455955847
# 	Unqualified candidate feature skipped ~
# * Candidate feature: Interaction --> ECR value: 20.3622057797
# 	Qualified candidate feature added +
# * Candidate feature: AppCount --> ECR value: 20.3497939088
# 	Qualified candidate feature added +
# * Candidate feature: ruleScoreTAUT --> ECR value: 19.9521465464
# 	Qualified candidate feature added +
# * Candidate feature: OptionalCount --> ECR value: 20.4943588976
# 	Qualified candidate feature added +
# * Candidate feature: cumul_F1Score --> ECR value: 14.9261928584
# 	Unqualified candidate feature skipped ~
# * Candidate feature: UseCount --> ECR value: 20.1393876648
# 	Qualified candidate feature added +
# >>> test subset ECR ...
# !!!Better optimal feature subset is discovered!!!
# 	Remove feature probIndexinLevel
# Max ECR touched so far: 20.1393876648 with 2 optimal features as:
# ['probIndexinLevel', 'UseCount']
# Highest valid ECR so far: 20.1393876648 with 2 optimal features as:
# ['probIndexinLevel', 'UseCount']
#
# ********* Search next feature on level <2> *********
# >>> Select candidate feature set ...
# * Candidate feature: cumul_probIndexinLevel --> ECR value: 20.1393876648
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimeWE --> ECR value: 36.2275492616
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimeDeviationWE --> ECR value: 31.7359289423
# 	Qualified candidate feature added +
# * Candidate feature: difficultProblemCountSolved --> ECR value: 35.7929557292
# 	Qualified candidate feature added +
# * Candidate feature: cumul_NonPSelements --> ECR value: 21.2034131577
# 	Qualified candidate feature added +
# * Candidate feature: cumul_DirectProofActionCount --> ECR value: 21.1768036395
# 	Qualified candidate feature added +
# * Candidate feature: difficultProblemCountWE --> ECR value: 19.0029766183
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_Interaction --> ECR value: 21.0116667604
# 	Qualified candidate feature added +
# * Candidate feature: cumul_actionCount --> ECR value: 21.1000718462
# 	Qualified candidate feature added +
# * Candidate feature: cumul_FDActionCount --> ECR value: 21.2977942195
# 	Qualified candidate feature added +
# * Candidate feature: cumul_WrongApp --> ECR value: 20.8818627985
# 	Qualified candidate feature added +
# * Candidate feature: cumul_symbolicRepresentationCount --> ECR value: 26.0136454979
# 	Qualified candidate feature added +
# * Candidate feature: cumul_WrongSyntaxApp --> ECR value: 21.8491141521
# 	Qualified candidate feature added +
# * Candidate feature: cumul_InterfaceErrorCount --> ECR value: 20.2058399252
# 	Qualified candidate feature added +
# * Candidate feature: cumul_TotalPSTime --> ECR value: 21.1840156263
# 	Qualified candidate feature added +
# * Candidate feature: cumul_AppCount --> ECR value: 21.3113098397
# 	Qualified candidate feature added +
# * Candidate feature: cumul_easyProblemCountSolved --> ECR value: 25.0894795676
# 	Qualified candidate feature added +
# * Candidate feature: cumul_WrongSemanticsApp --> ECR value: 19.9436984608
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_PrepCount --> ECR value: 21.7845625003
# 	Qualified candidate feature added +
# * Candidate feature: cumul_TotalTime --> ECR value: 20.3005354737
# 	Qualified candidate feature added +
# * Candidate feature: cumul_UseCount --> ECR value: 20.4111997633
# 	Qualified candidate feature added +
# * Candidate feature: cumul_MorphCount --> ECR value: 21.7974832312
# 	Qualified candidate feature added +
# * Candidate feature: cumul_RuleTypesCount --> ECR value: 23.1731545013
# 	Qualified candidate feature added +
# * Candidate feature: probIndexPSinLevel --> ECR value: 19.6931678572
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_hintCount --> ECR value: 19.4346685301
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_hintRatio --> ECR value: 19.4346685301
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_OptionalCount --> ECR value: 23.0715299268
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_NumProbRule --> ECR value: 23.7526428017
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimeDeviationPS --> ECR value: 23.5392436406
# 	Qualified candidate feature added +
# * Candidate feature: SeenWEinLevel --> ECR value: 18.596399866
# 	Unqualified candidate feature skipped ~
# * Candidate feature: NextStepClickCountWE --> ECR value: 18.5877502647
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_RightApp --> ECR value: 20.5160580357
# 	Qualified candidate feature added +
# * Candidate feature: TotalWETime --> ECR value: 18.7304896638
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_deletedApp --> ECR value: 21.9610231892
# 	Qualified candidate feature added +
# * Candidate feature: cumul_NextStepClickCountWE --> ECR value: 23.9725348029
# 	Qualified candidate feature added +
# * Candidate feature: WrongApp --> ECR value: 20.6628370025
# 	Qualified candidate feature added +
# * Candidate feature: WrongSyntaxApp --> ECR value: 20.1501421405
# 	Qualified candidate feature added +
# * Candidate feature: cumul_AppRatio --> ECR value: 21.2087514204
# 	Qualified candidate feature added +
# * Candidate feature: cumul_BlankRatio --> ECR value: 21.0761096405
# 	Qualified candidate feature added +
# * Candidate feature: cumul_englishSymbolicSwitchCount --> ECR value: 19.2886410369
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreCD --> ECR value: 19.850464976
# 	Unqualified candidate feature skipped ~
# * Candidate feature: easyProblemCountSolved --> ECR value: 24.6884702608
# 	Qualified candidate feature added +
# * Candidate feature: ruleScoreASSOC --> ECR value: 19.7984788048
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_avgstepTimeWE --> ECR value: 20.6014414599
# 	Qualified candidate feature added +
# * Candidate feature: WrongSemanticsApp --> ECR value: 20.9781913755
# 	Qualified candidate feature added +
# * Candidate feature: ruleScoreDIST --> ECR value: 19.7524199341
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalPSTime --> ECR value: 21.113969026
# 	Qualified candidate feature added +
# * Candidate feature: cumul_HoverHintCount --> ECR value: 17.8687385452
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_SystemInfoHintCount --> ECR value: 19.157117262
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreEXP --> ECR value: 19.8996606421
# 	Unqualified candidate feature skipped ~
# * Candidate feature: FDActionCount --> ECR value: 20.3031170007
# 	Qualified candidate feature added +
# * Candidate feature: actionCount --> ECR value: 20.3159496999
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimePS --> ECR value: 18.7211936404
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreCOM --> ECR value: 19.6736152232
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_medianProbTime --> ECR value: 17.7156814395
# 	Unqualified candidate feature skipped ~
# * Candidate feature: Interaction --> ECR value: 20.1930003793
# 	Qualified candidate feature added +
# * Candidate feature: AppCount --> ECR value: 20.4575330854
# 	Qualified candidate feature added +
# * Candidate feature: ruleScoreTAUT --> ECR value: 19.8027428275
# 	Unqualified candidate feature skipped ~
# * Candidate feature: OptionalCount --> ECR value: 21.5141168614
# 	Qualified candidate feature added +
# * Candidate feature: cumul_F1Score --> ECR value: 18.2462654662
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalTime --> ECR value: 21.8062719478
# 100% |########################################################################|
#   0% |                                                                        |
# 	Qualified candidate feature added +
# >>> test subset ECR ...
# !!!Better optimal feature subset is discovered!!!
# 	Remove feature probIndexinLevel
# !!!Better optimal feature subset is discovered!!!
#   4% |###                                                                     |
# 	Remove feature UseCount
# !!!Better optimal feature subset is discovered!!!
#   9% |#######                                                                 |
# 	Remove feature UseCount
# Max ECR touched so far: 36.0716146758 with 2 optimal features as:
# ['probIndexinLevel', 'difficultProblemCountSolved']
# Highest valid ECR so far: 36.0716146758 with 2 optimal features as:
# ['probIndexinLevel', 'difficultProblemCountSolved']
#
# ********* Search next feature on level <2> *********
# >>> Select candidate feature set ...
# * Candidate feature: cumul_probIndexinLevel --> ECR value: 36.0716146758
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimeWE --> ECR value: 64.4598094968
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimeDeviationWE --> ECR value: 50.0209846235
# 	Qualified candidate feature added +
# * Candidate feature: cumul_NonPSelements --> ECR value: 33.9340771807
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_DirectProofActionCount --> ECR value: 35.5997985407
# 	Unqualified candidate feature skipped ~
# * Candidate feature: difficultProblemCountWE --> ECR value: 30.6941821306
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_Interaction --> ECR value: 34.9680479929
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_actionCount --> ECR value: 34.8643852091
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_FDActionCount --> ECR value: 35.1120865954
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_WrongApp --> ECR value: 34.9735092449
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_symbolicRepresentationCount --> ECR value: 39.0519530328
# 	Qualified candidate feature added +
# * Candidate feature: cumul_WrongSyntaxApp --> ECR value: 36.2071122828
# 	Qualified candidate feature added +
# * Candidate feature: cumul_InterfaceErrorCount --> ECR value: 33.7243108801
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_TotalPSTime --> ECR value: 34.7299482943
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_AppCount --> ECR value: 35.3600194991
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_easyProblemCountSolved --> ECR value: 38.1508058796
# 	Qualified candidate feature added +
# * Candidate feature: cumul_WrongSemanticsApp --> ECR value: 35.4708656721
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_PrepCount --> ECR value: 34.7513012871
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_TotalTime --> ECR value: 35.5576314169
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_UseCount --> ECR value: 34.0214940554
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_MorphCount --> ECR value: 36.3307383589
# 	Qualified candidate feature added +
# * Candidate feature: cumul_RuleTypesCount --> ECR value: 36.2829742002
# 	Qualified candidate feature added +
# * Candidate feature: probIndexPSinLevel --> ECR value: 34.2012957543
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_hintCount --> ECR value: 34.7190298021
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_hintRatio --> ECR value: 34.7031880357
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_OptionalCount --> ECR value: 35.8823477748
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_NumProbRule --> ECR value: 43.687973601
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimeDeviationPS --> ECR value: 30.740372835
# 	Unqualified candidate feature skipped ~
# * Candidate feature: SeenWEinLevel --> ECR value: 30.896647486
# 	Unqualified candidate feature skipped ~
# * Candidate feature: NextStepClickCountWE --> ECR value: 30.8986434042
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_RightApp --> ECR value: 34.0480241733
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalWETime --> ECR value: 30.6475896037
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_deletedApp --> ECR value: 36.402044129
# 	Qualified candidate feature added +
# * Candidate feature: cumul_NextStepClickCountWE --> ECR value: 42.7024161691
# 	Qualified candidate feature added +
# * Candidate feature: WrongApp --> ECR value: 36.2227994642
# 	Qualified candidate feature added +
# * Candidate feature: WrongSyntaxApp --> ECR value: 36.5773812993
# 	Qualified candidate feature added +
# * Candidate feature: cumul_AppRatio --> ECR value: 37.1747637892
# 	Qualified candidate feature added +
# * Candidate feature: cumul_BlankRatio --> ECR value: 37.0181165765
# 	Qualified candidate feature added +
# * Candidate feature: cumul_englishSymbolicSwitchCount --> ECR value: 33.6719611545
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreCD --> ECR value: 34.9721608918
# 	Unqualified candidate feature skipped ~
# * Candidate feature: easyProblemCountSolved --> ECR value: 38.0978072633
# 	Qualified candidate feature added +
# * Candidate feature: ruleScoreASSOC --> ECR value: 35.1542458664
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_avgstepTimeWE --> ECR value: 32.4400304396
# 	Unqualified candidate feature skipped ~
# * Candidate feature: WrongSemanticsApp --> ECR value: 34.6780657002
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreDIST --> ECR value: 35.6621550532
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalPSTime --> ECR value: 35.1029165403
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_HoverHintCount --> ECR value: 38.3726018063
# 	Qualified candidate feature added +
# * Candidate feature: cumul_SystemInfoHintCount --> ECR value: 32.8312429526
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreEXP --> ECR value: 34.9910075897
# 	Unqualified candidate feature skipped ~
# * Candidate feature: FDActionCount --> ECR value: 35.0458817871
# 	Unqualified candidate feature skipped ~
# * Candidate feature: actionCount --> ECR value: 35.0270299936
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_avgProbTimePS --> ECR value: 30.5982931699
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreCOM --> ECR value: 35.1115469654
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_medianProbTime --> ECR value: 32.1503312002
# 	Unqualified candidate feature skipped ~
# * Candidate feature: Interaction --> ECR value: 34.079188805
# 	Unqualified candidate feature skipped ~
# * Candidate feature: AppCount --> ECR value: 34.2786377827
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreTAUT --> ECR value: 34.9054924975
# 	Unqualified candidate feature skipped ~
# * Candidate feature: OptionalCount --> ECR value: 36.4017322838
# 	Qualified candidate feature added +
# * Candidate feature: cumul_F1Score --> ECR value: 39.3331591321
# 	Qualified candidate feature added +
# * Candidate feature: UseCount --> ECR value: 35.7929557292
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalTime --> ECR value: 33.3278815451
# 100% |########################################################################|
#   0% |                                                                        |
# 	Unqualified candidate feature skipped ~
# >>> test subset ECR ...
# !!!Better optimal feature subset is discovered!!!
# 	Remove feature probIndexinLevel
# !!!Better optimal feature subset is discovered!!!
#  10% |#######                                                                 |
# 	Remove feature probIndexinLevel
# Max ECR touched so far: 50.0209846235 with 3 optimal features as:
# ['probIndexinLevel', 'difficultProblemCountSolved', 'CurrPro_avgProbTimeDeviationWE']
# Highest valid ECR so far: 50.0209846235 with 3 optimal features as:
# ['probIndexinLevel', 'difficultProblemCountSolved', 'CurrPro_avgProbTimeDeviationWE']
#
# ********* Search next feature on level <3> *********
# >>> Select candidate feature set ...
# * Candidate feature: cumul_probIndexinLevel --> ECR value: 50.0209846235
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_avgProbTimeWE --> ECR value: 51.7026621442
# 	Qualified candidate feature added +
# * Candidate feature: cumul_NonPSelements --> ECR value: 50.7475448015
# 	Qualified candidate feature added +
# * Candidate feature: cumul_DirectProofActionCount --> ECR value: 48.8919541983
# 	Unqualified candidate feature skipped ~
# * Candidate feature: difficultProblemCountWE --> ECR value: 40.2957467205
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_Interaction --> ECR value: 48.2937358017
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_actionCount --> ECR value: 48.4680360072
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_FDActionCount --> ECR value: 48.3613767482
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_WrongApp --> ECR value: 48.9994828595
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_symbolicRepresentationCount --> ECR value: 52.7420886645
# 	Qualified candidate feature added +
# * Candidate feature: cumul_WrongSyntaxApp --> ECR value: 51.3459798282
# 	Qualified candidate feature added +
# * Candidate feature: cumul_InterfaceErrorCount --> ECR value: 46.2992552124
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_TotalPSTime --> ECR value: 48.2463223511
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_AppCount --> ECR value: 47.7670961575
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_easyProblemCountSolved --> ECR value: 52.3174931348
# 	Qualified candidate feature added +
# * Candidate feature: cumul_WrongSemanticsApp --> ECR value: 50.4724342755
# 	Qualified candidate feature added +
# * Candidate feature: cumul_PrepCount --> ECR value: 50.1768210626
# 	Qualified candidate feature added +
# * Candidate feature: cumul_TotalTime --> ECR value: 49.7531864177
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_UseCount --> ECR value: 48.6882322388
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_MorphCount --> ECR value: 49.6140196034
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_RuleTypesCount --> ECR value: 49.7431012146
# 	Unqualified candidate feature skipped ~
# * Candidate feature: probIndexPSinLevel --> ECR value: 45.4557205949
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_hintCount --> ECR value: 50.1996165078
# 	Qualified candidate feature added +
# * Candidate feature: cumul_hintRatio --> ECR value: 50.1669237777
# 	Qualified candidate feature added +
# * Candidate feature: cumul_OptionalCount --> ECR value: 49.6618633534
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_NumProbRule --> ECR value: 54.5824549283
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimeDeviationPS --> ECR value: 36.0174405966
# 	Unqualified candidate feature skipped ~
# * Candidate feature: SeenWEinLevel --> ECR value: 40.6682285043
# 	Unqualified candidate feature skipped ~
# * Candidate feature: NextStepClickCountWE --> ECR value: 40.679389156
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_RightApp --> ECR value: 45.7679235587
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalWETime --> ECR value: 40.7641375704
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_deletedApp --> ECR value: 49.4379887489
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_NextStepClickCountWE --> ECR value: 48.7881237647
# 	Unqualified candidate feature skipped ~
# * Candidate feature: WrongApp --> ECR value: 49.1835688692
# 	Unqualified candidate feature skipped ~
# * Candidate feature: WrongSyntaxApp --> ECR value: 50.3063698449
# 	Qualified candidate feature added +
# * Candidate feature: cumul_AppRatio --> ECR value: 50.4803296681
# 	Qualified candidate feature added +
# * Candidate feature: cumul_BlankRatio --> ECR value: 50.5198519108
# 	Qualified candidate feature added +
# * Candidate feature: cumul_englishSymbolicSwitchCount --> ECR value: 47.6955580794
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreCD --> ECR value: 49.4310011989
# 	Unqualified candidate feature skipped ~
# * Candidate feature: easyProblemCountSolved --> ECR value: 52.65941475
# 	Qualified candidate feature added +
# * Candidate feature: ruleScoreASSOC --> ECR value: 47.0606843861
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_avgstepTimeWE --> ECR value: 49.679658018
# 	Unqualified candidate feature skipped ~
# * Candidate feature: WrongSemanticsApp --> ECR value: 46.2351777412
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreDIST --> ECR value: 48.6528909004
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalPSTime --> ECR value: 48.6487188677
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_HoverHintCount --> ECR value: 50.8226555886
# 	Qualified candidate feature added +
# * Candidate feature: cumul_SystemInfoHintCount --> ECR value: 46.3900397924
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreEXP --> ECR value: 48.4188472503
# 	Unqualified candidate feature skipped ~
# * Candidate feature: FDActionCount --> ECR value: 48.5395581842
# 	Unqualified candidate feature skipped ~
# * Candidate feature: actionCount --> ECR value: 48.5261654008
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_avgProbTimePS --> ECR value: 42.7499280664
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreCOM --> ECR value: 47.612934329
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_medianProbTime --> ECR value: 42.6527764489
# 	Unqualified candidate feature skipped ~
# * Candidate feature: Interaction --> ECR value: 47.9115730345
# 	Unqualified candidate feature skipped ~
# * Candidate feature: AppCount --> ECR value: 45.6676247556
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreTAUT --> ECR value: 46.923269057
# 	Unqualified candidate feature skipped ~
# * Candidate feature: OptionalCount --> ECR value: 50.7303906792
# 	Qualified candidate feature added +
# * Candidate feature: cumul_F1Score --> ECR value: 51.9090972286
# 	Qualified candidate feature added +
# * Candidate feature: UseCount --> ECR value: 49.1172311515
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalTime --> ECR value: 45.3470971209
# 100% |########################################################################|
#   0% |                                                                        |
# 	Unqualified candidate feature skipped ~
# >>> test subset ECR ...
# !!!Better optimal feature subset is discovered!!!
# 	Remove feature CurrPro_avgProbTimeDeviationWE
# Max ECR touched so far: 64.4598094968 with 3 optimal features as:
# ['probIndexinLevel', 'difficultProblemCountSolved', 'CurrPro_avgProbTimeWE']
# Highest valid ECR so far: 64.4598094968 with 3 optimal features as:
# ['probIndexinLevel', 'difficultProblemCountSolved', 'CurrPro_avgProbTimeWE']
#
# ********* Search next feature on level <3> *********
# >>> Select candidate feature set ...
# * Candidate feature: cumul_probIndexinLevel --> ECR value: 64.4598094968
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimeDeviationWE --> ECR value: 51.7026621442
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_NonPSelements --> ECR value: 63.7704191981
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_DirectProofActionCount --> ECR value: 61.2208484322
# 	Unqualified candidate feature skipped ~
# * Candidate feature: difficultProblemCountWE --> ECR value: 46.3710930916
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_Interaction --> ECR value: 59.8627637168
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_actionCount --> ECR value: 60.0721166645
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_FDActionCount --> ECR value: 60.0609598223
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_WrongApp --> ECR value: 63.1673309142
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_symbolicRepresentationCount --> ECR value: 64.9274500071
# 	Qualified candidate feature added +
# * Candidate feature: cumul_WrongSyntaxApp --> ECR value: 66.0173592854
# 	Qualified candidate feature added +
# * Candidate feature: cumul_InterfaceErrorCount --> ECR value: 58.5075194318
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_TotalPSTime --> ECR value: 61.9292670843
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_AppCount --> ECR value: 60.3598152621
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_easyProblemCountSolved --> ECR value: 63.7277828301
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_WrongSemanticsApp --> ECR value: 65.5852072081
# 	Qualified candidate feature added +
# * Candidate feature: cumul_PrepCount --> ECR value: 63.9746960062
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_TotalTime --> ECR value: 64.1149025007
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_UseCount --> ECR value: 62.0754576478
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_MorphCount --> ECR value: 62.6868720014
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_RuleTypesCount --> ECR value: 64.428883464
# 	Unqualified candidate feature skipped ~
# * Candidate feature: probIndexPSinLevel --> ECR value: 56.4486692949
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_hintCount --> ECR value: 65.1522135343
# 	Qualified candidate feature added +
# * Candidate feature: cumul_hintRatio --> ECR value: 65.1187759153
# 	Qualified candidate feature added +
# * Candidate feature: cumul_OptionalCount --> ECR value: 62.5291382827
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_NumProbRule --> ECR value: 64.7997719098
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimeDeviationPS --> ECR value: 41.2240957407
# 	Unqualified candidate feature skipped ~
# * Candidate feature: SeenWEinLevel --> ECR value: 47.6308054032
# 	Unqualified candidate feature skipped ~
# * Candidate feature: NextStepClickCountWE --> ECR value: 47.6349366984
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_RightApp --> ECR value: 56.5795233954
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalWETime --> ECR value: 47.5882405913
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_deletedApp --> ECR value: 63.9685324665
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_NextStepClickCountWE --> ECR value: 65.623618325
# 	Qualified candidate feature added +
# * Candidate feature: WrongApp --> ECR value: 59.7444943085
# 	Unqualified candidate feature skipped ~
# * Candidate feature: WrongSyntaxApp --> ECR value: 62.0533411621
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_AppRatio --> ECR value: 66.3175796467
# 	Qualified candidate feature added +
# * Candidate feature: cumul_BlankRatio --> ECR value: 66.3076438386
# 	Qualified candidate feature added +
# * Candidate feature: cumul_englishSymbolicSwitchCount --> ECR value: 61.7004992594
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreCD --> ECR value: 56.7825722553
# 	Unqualified candidate feature skipped ~
# * Candidate feature: easyProblemCountSolved --> ECR value: 65.0523900559
# 	Qualified candidate feature added +
# * Candidate feature: ruleScoreASSOC --> ECR value: 59.0355565288
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_avgstepTimeWE --> ECR value: 64.6276649036
# 	Qualified candidate feature added +
# * Candidate feature: WrongSemanticsApp --> ECR value: 56.1047908201
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreDIST --> ECR value: 58.9646567392
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalPSTime --> ECR value: 58.5746215606
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_HoverHintCount --> ECR value: 64.7726819996
# 	Qualified candidate feature added +
# * Candidate feature: cumul_SystemInfoHintCount --> ECR value: 57.916380616
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreEXP --> ECR value: 59.7742705607
# 	Unqualified candidate feature skipped ~
# * Candidate feature: FDActionCount --> ECR value: 57.9755675478
# 	Unqualified candidate feature skipped ~
# * Candidate feature: actionCount --> ECR value: 57.951203294
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_avgProbTimePS --> ECR value: 57.4682949604
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreCOM --> ECR value: 58.6862787091
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_medianProbTime --> ECR value: 55.6151448625
# 	Unqualified candidate feature skipped ~
# * Candidate feature: Interaction --> ECR value: 56.5935900521
# 	Unqualified candidate feature skipped ~
# * Candidate feature: AppCount --> ECR value: 53.9927517952
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreTAUT --> ECR value: 57.687693494
# 	Unqualified candidate feature skipped ~
# * Candidate feature: OptionalCount --> ECR value: 60.9877758776
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_F1Score --> ECR value: 66.6792880559
# 	Qualified candidate feature added +
# * Candidate feature: UseCount --> ECR value: 63.9382812972
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalTime --> ECR value: 58.1023831202
# 100% |########################################################################|
# 	Unqualified candidate feature skipped ~
# >>> test subset ECR ...
# Max ECR touched so far: 66.6792880559 with 4 optimal features as:
# ['probIndexinLevel', 'difficultProblemCountSolved', 'CurrPro_avgProbTimeWE', 'cumul_F1Score']
# Highest valid ECR so far: 66.6792880559 with 4 optimal features as:
# ['probIndexinLevel', 'difficultProblemCountSolved', 'CurrPro_avgProbTimeWE', 'cumul_F1Score']
#
# ********* Search next feature on level <4> *********
# >>> Select candidate feature set ...
# * Candidate feature: cumul_probIndexinLevel --> ECR value: 66.6792880559
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimeDeviationWE --> ECR value: 53.4465321134
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_NonPSelements --> ECR value: 62.9319912062
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_DirectProofActionCount --> ECR value: 62.5376658881
# 	Unqualified candidate feature skipped ~
# * Candidate feature: difficultProblemCountWE --> ECR value: 46.2446721818
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_Interaction --> ECR value: 61.1904931928
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_actionCount --> ECR value: 61.7487727241
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_FDActionCount --> ECR value: 61.6795146119
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_WrongApp --> ECR value: 62.2642764992
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_symbolicRepresentationCount --> ECR value: 66.03597042
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_WrongSyntaxApp --> ECR value: 65.9911450019
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_InterfaceErrorCount --> ECR value: 57.9770954366
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_TotalPSTime --> ECR value: 61.5720548714
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_AppCount --> ECR value: 62.326462622
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_easyProblemCountSolved --> ECR value: 65.9291510564
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_WrongSemanticsApp --> ECR value: 64.6872675133
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_PrepCount --> ECR value: 63.7016914347
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_TotalTime --> ECR value: 63.6452866315
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_UseCount --> ECR value: 61.6900032377
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_MorphCount --> ECR value: 63.835126592
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_RuleTypesCount --> ECR value: 64.57105297
# 	Unqualified candidate feature skipped ~
# * Candidate feature: probIndexPSinLevel --> ECR value: 57.4360317919
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_hintCount --> ECR value: 64.0903809474
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_hintRatio --> ECR value: 64.0359711339
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_OptionalCount --> ECR value: 64.0402794579
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_NumProbRule --> ECR value: 70.2286504252
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimeDeviationPS --> ECR value: 45.3064368849
# 	Unqualified candidate feature skipped ~
# * Candidate feature: SeenWEinLevel --> ECR value: 47.8307807335
# 	Unqualified candidate feature skipped ~
# * Candidate feature: NextStepClickCountWE --> ECR value: 47.8253222404
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_RightApp --> ECR value: 58.7784804365
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalWETime --> ECR value: 47.5961098286
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_deletedApp --> ECR value: 64.4960870043
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_NextStepClickCountWE --> ECR value: 67.2140141401
# 	Qualified candidate feature added +
# * Candidate feature: WrongApp --> ECR value: 60.508099738
# 	Unqualified candidate feature skipped ~
# * Candidate feature: WrongSyntaxApp --> ECR value: 63.1948146729
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_AppRatio --> ECR value: 73.3212697462
# 	Qualified candidate feature added +
# * Candidate feature: cumul_BlankRatio --> ECR value: 73.1396518483
# 	Qualified candidate feature added +
# * Candidate feature: cumul_englishSymbolicSwitchCount --> ECR value: 59.2854045231
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreCD --> ECR value: 54.4852529018
# 	Unqualified candidate feature skipped ~
# * Candidate feature: easyProblemCountSolved --> ECR value: 67.2042633147
# 	Qualified candidate feature added +
# * Candidate feature: ruleScoreASSOC --> ECR value: 58.1511160124
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_avgstepTimeWE --> ECR value: 64.7708237103
# 	Unqualified candidate feature skipped ~
# * Candidate feature: WrongSemanticsApp --> ECR value: 54.9487423381
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreDIST --> ECR value: 59.5619456112
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalPSTime --> ECR value: 57.3675778052
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_HoverHintCount --> ECR value: 64.1629703633
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_SystemInfoHintCount --> ECR value: 59.4044428286
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreEXP --> ECR value: 57.5920590205
# 	Unqualified candidate feature skipped ~
# * Candidate feature: FDActionCount --> ECR value: 59.8666967997
# 	Unqualified candidate feature skipped ~
# * Candidate feature: actionCount --> ECR value: 59.8430440697
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_avgProbTimePS --> ECR value: 59.5442878671
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreCOM --> ECR value: 59.3814018761
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_medianProbTime --> ECR value: 56.1454770482
# 	Unqualified candidate feature skipped ~
# * Candidate feature: Interaction --> ECR value: 57.9285881146
# 	Unqualified candidate feature skipped ~
# * Candidate feature: AppCount --> ECR value: 57.1716235408
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreTAUT --> ECR value: 56.8811453619
# 	Unqualified candidate feature skipped ~
# * Candidate feature: OptionalCount --> ECR value: 62.2334939383
# 	Unqualified candidate feature skipped ~
# * Candidate feature: UseCount --> ECR value: 64.1272146999
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalTime --> ECR value: 58.0684326746
# 	Unqualified candidate feature skipped ~
# * Candidate feature: probAlternate --> ECR value: 66.9452837723
#   0% |                                                                        |
# 	Qualified candidate feature added +
# >>> test subset ECR ...
# !!!Better optimal feature subset is discovered!!!
# 	Remove feature probIndexinLevel
# Max ECR touched so far: 66.9452837723 with 5 optimal features as:
# ['probIndexinLevel', 'difficultProblemCountSolved', 'CurrPro_avgProbTimeWE', 'cumul_F1Score', 'probAlternate']
# Highest valid ECR so far: 66.9452837723 with 5 optimal features as:
# ['probIndexinLevel', 'difficultProblemCountSolved', 'CurrPro_avgProbTimeWE', 'cumul_F1Score', 'probAlternate']
#
# ********* Search next feature on level <5> *********
# >>> Select candidate feature set ...
# * Candidate feature: cumul_probIndexinLevel --> ECR value: 66.9452837723
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimeDeviationWE --> ECR value: 53.6275343326
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_NonPSelements --> ECR value: 63.1595789454
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_DirectProofActionCount --> ECR value: 63.0097019379
# 	Unqualified candidate feature skipped ~
# * Candidate feature: difficultProblemCountWE --> ECR value: 46.391428625
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_Interaction --> ECR value: 61.6485215977
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_actionCount --> ECR value: 62.1607647283
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_FDActionCount --> ECR value: 62.100530542
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_WrongApp --> ECR value: 62.5880304029
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_symbolicRepresentationCount --> ECR value: 66.2340028605
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_WrongSyntaxApp --> ECR value: 66.3138116961
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_InterfaceErrorCount --> ECR value: 58.7983131324
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_TotalPSTime --> ECR value: 61.8817215238
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_AppCount --> ECR value: 62.7145548508
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_easyProblemCountSolved --> ECR value: 66.1798535961
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_WrongSemanticsApp --> ECR value: 65.0044176226
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_PrepCount --> ECR value: 64.0886085993
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_TotalTime --> ECR value: 64.0207124568
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_UseCount --> ECR value: 62.1808442417
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_MorphCount --> ECR value: 64.102521597
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_RuleTypesCount --> ECR value: 64.8208469988
# 	Unqualified candidate feature skipped ~
# * Candidate feature: probIndexPSinLevel --> ECR value: 55.0639167586
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_hintCount --> ECR value: 64.27196215
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_hintRatio --> ECR value: 64.2180965836
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_OptionalCount --> ECR value: 64.2745225427
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_NumProbRule --> ECR value: 70.4591845427
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimeDeviationPS --> ECR value: 45.09716056
# 	Unqualified candidate feature skipped ~
# * Candidate feature: SeenWEinLevel --> ECR value: 48.8652432921
# 	Unqualified candidate feature skipped ~
# * Candidate feature: NextStepClickCountWE --> ECR value: 48.8596997031
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_RightApp --> ECR value: 59.1237123888
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalWETime --> ECR value: 48.6336971709
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_deletedApp --> ECR value: 64.7183837693
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_NextStepClickCountWE --> ECR value: 67.522456604
# 	Qualified candidate feature added +
# * Candidate feature: WrongApp --> ECR value: 60.5980298292
# 	Unqualified candidate feature skipped ~
# * Candidate feature: WrongSyntaxApp --> ECR value: 63.3484460561
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_AppRatio --> ECR value: 73.6005664875
# 	Qualified candidate feature added +
# * Candidate feature: cumul_BlankRatio --> ECR value: 73.423435666
# 	Qualified candidate feature added +
# * Candidate feature: cumul_englishSymbolicSwitchCount --> ECR value: 59.610388532
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreCD --> ECR value: 54.9018634694
# 	Unqualified candidate feature skipped ~
# * Candidate feature: easyProblemCountSolved --> ECR value: 67.3709398034
# 	Qualified candidate feature added +
# * Candidate feature: ruleScoreASSOC --> ECR value: 58.5300893768
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_avgstepTimeWE --> ECR value: 65.0589127533
# 	Unqualified candidate feature skipped ~
# * Candidate feature: WrongSemanticsApp --> ECR value: 55.0511625476
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreDIST --> ECR value: 59.7738907949
# ...
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_HoverHintCount --> ECR value: 292.048510722
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_SystemInfoHintCount --> ECR value: 312.624728298
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreEXP --> ECR value: 310.797046301
# 	Unqualified candidate feature skipped ~
# * Candidate feature: FDActionCount --> ECR value: 64.7363487371
# 	Unqualified candidate feature skipped ~
# * Candidate feature: actionCount --> ECR value: 64.6773236945
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_avgProbTimePS --> ECR value: 300.403072479
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreCOM --> ECR value: 305.617274932
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_medianProbTime --> ECR value: 232.968866059
# 	Unqualified candidate feature skipped ~
# * Candidate feature: Interaction --> ECR value: 64.5474861702
# 	Unqualified candidate feature skipped ~
# * Candidate feature: AppCount --> ECR value: 68.3248206836
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreTAUT --> ECR value: 323.787974622
# 	Unqualified candidate feature skipped ~
# * Candidate feature: OptionalCount --> ECR value: 322.489781507
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_F1Score --> ECR value: 285.604425819
# 	Unqualified candidate feature skipped ~
# * Candidate feature: UseCount --> ECR value: 83.8768290077
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalTime --> ECR value: 68.0282005168
# 	Unqualified candidate feature skipped ~
# * Candidate feature: probAlternate --> ECR value: 348.695312055
# 	Qualified candidate feature added +
# * Candidate feature: easyProbAlternate --> ECR value: 348.695312055
# 	Qualified candidate feature added +
# * Candidate feature: cumul_probAlternate --> ECR value: 348.695312055
# 	Qualified candidate feature added +
# * Candidate feature: cumul_easyProbAlternate --> ECR value: 348.695312055
# 	Qualified candidate feature added +
# * Candidate feature: PrepCount --> ECR value: 107.32238573
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_PrightAppRatio --> ECR value: 285.549563614
# 	Unqualified candidate feature skipped ~
# * Candidate feature: PreviousStepClickCountWE --> ECR value: 339.835190279
# 	Unqualified candidate feature skipped ~
# * Candidate feature: NonPSelements --> ECR value: 343.741644251
# 	Unqualified candidate feature skipped ~
# * Candidate feature: DirectProofActionCount --> ECR value: 67.9272612306
# 	Unqualified candidate feature skipped ~
# * Candidate feature: avgstepTimePS --> ECR value: 54.4037434902
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_difficultProblemCountSolved --> ECR value: 307.405182375
# 	Unqualified candidate feature skipped ~
# * Candidate feature: InterfaceErrorCount --> ECR value: 239.575546235
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_BDActionCount --> ECR value: 332.724199995
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreABS --> ECR value: 335.795181591
# 	Unqualified candidate feature skipped ~
# * Candidate feature: HoverHintCount --> ECR value: 286.877340299
# 	Unqualified candidate feature skipped ~
# * Candidate feature: MorphCount --> ECR value: 248.168012905
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_InDirectProofActionCount --> ECR value: 100.749174327
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_RrightAppRatio --> ECR value: 56.6475028919
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_UseWindowInfo --> ECR value: 342.668985774
# 	Unqualified candidate feature skipped ~
# * Candidate feature: RuleTypesCount --> ECR value: 133.970147739
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_avgstepTimePS --> ECR value: 94.8371979316
# 	Unqualified candidate feature skipped ~
# * Candidate feature: Level --> ECR value: 309.663614017
# 	Unqualified candidate feature skipped ~
# * Candidate feature: RrightAppRatio --> ECR value: 92.0144136971
# 	Unqualified candidate feature skipped ~
# * Candidate feature: hintRatio --> ECR value: 309.349655512
# 	Unqualified candidate feature skipped ~
# * Candidate feature: hintCount --> ECR value: 308.423334336
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_PreviousStepClickCountWE --> ECR value: 339.671655917
# 	Unqualified candidate feature skipped ~
# * Candidate feature: F1Score --> ECR value: 60.1442354079
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreDS --> ECR value: 167.125217922
# 	Unqualified candidate feature skipped ~
# * Candidate feature: PrightAppRatio --> ECR value: 282.890673423
# 	Unqualified candidate feature skipped ~
# * Candidate feature: BlankRatio --> ECR value: 321.105669494
#   0% |                                                                        |
# 	Unqualified candidate feature skipped ~
# >>> test subset ECR ...
# !!!Better optimal feature subset is discovered!!!
# 	Remove feature probIndexinLevel
# Max ECR touched so far: 351.630883377 with 8 optimal features as:
# ['difficultProblemCountSolved', 'cumul_BlankRatio', 'cumul_MorphCount', 'CurrPro_avgProbTimeDeviationPS', 'cumul_FDActionCount', 'ruleScoreEQUIV', 'cumul_TotalWETime', 'cumul_symbolicRepresentationCount']
# Highest valid ECR so far: 351.630883377 with 8 optimal features as:
# ['difficultProblemCountSolved', 'cumul_BlankRatio', 'cumul_MorphCount', 'CurrPro_avgProbTimeDeviationPS', 'cumul_FDActionCount', 'ruleScoreEQUIV', 'cumul_TotalWETime', 'cumul_symbolicRepresentationCount']
#
# ********* Search next feature on level <8> *********
# >>> Select candidate feature set ...
# * Candidate feature: probIndexinLevel --> ECR value: 356.323704852
# 	Qualified candidate feature added +
# * Candidate feature: cumul_probIndexinLevel --> ECR value: 356.323704852
# 	Qualified candidate feature added +
# * Candidate feature: CurrPro_avgProbTimeWE --> ECR value: 345.077229549
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_avgProbTimeDeviationWE --> ECR value: 283.601642798
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_NonPSelements --> ECR value: 353.247912765
# 	Qualified candidate feature added +
# * Candidate feature: cumul_DirectProofActionCount --> ECR value: 341.821084464
# 	Unqualified candidate feature skipped ~
# * Candidate feature: difficultProblemCountWE --> ECR value: 296.950802867
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_Interaction --> ECR value: 337.125411289
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_actionCount --> ECR value: 350.346964654
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_WrongApp --> ECR value: 43.3170418433
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_WrongSyntaxApp --> ECR value: 330.210889703
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_InterfaceErrorCount --> ECR value: 113.358146543
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_TotalPSTime --> ECR value: 102.312451731
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_AppCount --> ECR value: 334.955481576
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_easyProblemCountSolved --> ECR value: 352.084221364
# 	Qualified candidate feature added +
# * Candidate feature: cumul_WrongSemanticsApp --> ECR value: 44.9049812228
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_PrepCount --> ECR value: 41.5191529676
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_TotalTime --> ECR value: 103.681224566
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_UseCount --> ECR value: 327.045039659
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_RuleTypesCount --> ECR value: 333.013223577
# 	Unqualified candidate feature skipped ~
# * Candidate feature: probIndexPSinLevel --> ECR value: 332.724256897
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_hintCount --> ECR value: 312.247092646
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_hintRatio --> ECR value: 312.303912187
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_OptionalCount --> ECR value: 318.397088041
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_NumProbRule --> ECR value: 228.235141256
# 	Unqualified candidate feature skipped ~
# * Candidate feature: SeenWEinLevel --> ECR value: 349.764748342
# 	Unqualified candidate feature skipped ~
# * Candidate feature: NextStepClickCountWE --> ECR value: 349.588409962
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_RightApp --> ECR value: 333.649047921
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalWETime --> ECR value: 348.626891822
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_deletedApp --> ECR value: 87.7650197212
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_NextStepClickCountWE --> ECR value: 316.358827552
# 	Unqualified candidate feature skipped ~
# * Candidate feature: WrongApp --> ECR value: 189.047510098
# 	Unqualified candidate feature skipped ~
# * Candidate feature: WrongSyntaxApp --> ECR value: 73.4143754779
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_AppRatio --> ECR value: 352.331423598
# 	Qualified candidate feature added +
# * Candidate feature: cumul_englishSymbolicSwitchCount --> ECR value: 318.099048382
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreCD --> ECR value: 82.4812130813
# 	Unqualified candidate feature skipped ~
# * Candidate feature: easyProblemCountSolved --> ECR value: 351.218636428
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreASSOC --> ECR value: 318.89174463
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_avgstepTimeWE --> ECR value: 347.384382219
# 	Unqualified candidate feature skipped ~
# * Candidate feature: WrongSemanticsApp --> ECR value: 65.5410817876
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreDIST --> ECR value: 297.999711371
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalPSTime --> ECR value: 237.081994171
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_HoverHintCount --> ECR value: 289.257244762
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_SystemInfoHintCount --> ECR value: 338.147288607
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreEXP --> ECR value: 320.15514618
# 	Unqualified candidate feature skipped ~
# * Candidate feature: FDActionCount --> ECR value: 68.6851560442
# 	Unqualified candidate feature skipped ~
# * Candidate feature: actionCount --> ECR value: 68.6900892575
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_avgProbTimePS --> ECR value: 300.250918774
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreCOM --> ECR value: 318.434312452
# 	Unqualified candidate feature skipped ~
# * Candidate feature: CurrPro_medianProbTime --> ECR value: 244.103015386
# 	Unqualified candidate feature skipped ~
# * Candidate feature: Interaction --> ECR value: 70.0840502686
# 	Unqualified candidate feature skipped ~
# * Candidate feature: AppCount --> ECR value: 71.7803460048
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreTAUT --> ECR value: 322.811126814
# 	Unqualified candidate feature skipped ~
# * Candidate feature: OptionalCount --> ECR value: 323.150181284
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_F1Score --> ECR value: 289.529475178
# 	Unqualified candidate feature skipped ~
# * Candidate feature: UseCount --> ECR value: 89.7547905021
# 	Unqualified candidate feature skipped ~
# * Candidate feature: TotalTime --> ECR value: 70.8119398758
# 	Unqualified candidate feature skipped ~
# * Candidate feature: probAlternate --> ECR value: 353.46045925
# 	Qualified candidate feature added +
# * Candidate feature: easyProbAlternate --> ECR value: 353.46045925
# 	Qualified candidate feature added +
# * Candidate feature: cumul_probAlternate --> ECR value: 353.46045925
# 	Qualified candidate feature added +
# * Candidate feature: cumul_easyProbAlternate --> ECR value: 353.46045925
# 	Qualified candidate feature added +
# * Candidate feature: PrepCount --> ECR value: 111.659152081
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_PrightAppRatio --> ECR value: 291.292719384
# 	Unqualified candidate feature skipped ~
# * Candidate feature: PreviousStepClickCountWE --> ECR value: 347.422606992
# 	Unqualified candidate feature skipped ~
# * Candidate feature: NonPSelements --> ECR value: 342.191313099
# 	Unqualified candidate feature skipped ~
# * Candidate feature: DirectProofActionCount --> ECR value: 71.4466985431
# 	Unqualified candidate feature skipped ~
# * Candidate feature: avgstepTimePS --> ECR value: 59.1000776607
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_difficultProblemCountSolved --> ECR value: 315.998781989
# 	Unqualified candidate feature skipped ~
# * Candidate feature: InterfaceErrorCount --> ECR value: 253.625631965
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_BDActionCount --> ECR value: 329.598384878
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreABS --> ECR value: 330.212322084
# 	Unqualified candidate feature skipped ~
# * Candidate feature: HoverHintCount --> ECR value: 296.535548576
# 	Unqualified candidate feature skipped ~
# * Candidate feature: MorphCount --> ECR value: 257.216427398
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_InDirectProofActionCount --> ECR value: 102.879913432
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_RrightAppRatio --> ECR value: 53.9060803987
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_UseWindowInfo --> ECR value: 342.468476514
# 	Unqualified candidate feature skipped ~
# * Candidate feature: RuleTypesCount --> ECR value: 155.519876868
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_avgstepTimePS --> ECR value: 96.3279003489
# 	Unqualified candidate feature skipped ~
# * Candidate feature: Level --> ECR value: 295.499985692
# 	Unqualified candidate feature skipped ~
# * Candidate feature: RrightAppRatio --> ECR value: 91.231986892
# 	Unqualified candidate feature skipped ~
# * Candidate feature: hintRatio --> ECR value: 300.78564895
# 	Unqualified candidate feature skipped ~
# * Candidate feature: hintCount --> ECR value: 300.018340592
# 	Unqualified candidate feature skipped ~
# * Candidate feature: cumul_PreviousStepClickCountWE --> ECR value: 349.541631639
# 	Unqualified candidate feature skipped ~
# * Candidate feature: F1Score --> ECR value: 59.7416356368
# 	Unqualified candidate feature skipped ~
# * Candidate feature: ruleScoreDS --> ECR value: 175.668460978
# 	Unqualified candidate feature skipped ~
# * Candidate feature: PrightAppRatio --> ECR value: 284.416800189
# 	Unqualified candidate feature skipped ~
# * Candidate feature: BlankRatio --> ECR value: 320.802466456
# 100% |########################################################################|
# 	Unqualified candidate feature skipped ~
# >>> test subset ECR ...
# !!!Better optimal feature subset is discovered!!!
# 	Remove feature cumul_BlankRatio
# Max ECR touched so far: 353.46045925 with 9 optimal features as:
# ['difficultProblemCountSolved', 'cumul_BlankRatio', 'cumul_MorphCount', 'CurrPro_avgProbTimeDeviationPS', 'cumul_FDActionCount', 'ruleScoreEQUIV', 'cumul_TotalWETime', 'cumul_symbolicRepresentationCount', 'cumul_easyProbAlternate']
# Highest valid ECR so far: 352.596993622 with 8 optimal features as:
# ['difficultProblemCountSolved', 'cumul_MorphCount', 'CurrPro_avgProbTimeDeviationPS', 'cumul_FDActionCount', 'ruleScoreEQUIV', 'cumul_TotalWETime', 'cumul_symbolicRepresentationCount', 'cumul_AppRatio']
# 100% |########################################################################|

# %%
max_total_ECR = valid_max_total_ECR # retrieve upper limit ECR 
optimal_feature_set = valid_optimal_feature_set # retrieve feature set of upper limit ECR
time_cost = time.time() - start_time # time cost on feature selection

# %%
mf.induce_policy_MDP2(all_data_discretized, optimal_feature_set)
# Out:
# Policy:
# state -> action, value-function
# 1:0:1:0:1:1:0:0 -> PS, 330.173602171
# 1:1:1:0:0:1:0:0 -> PS, 458.131904362
# 0:1:1:0:1:0:0:0 -> PS, 375.998449566
# 0:1:0:0:0:0:1:0 -> PS, 288.343481064
# 1:1:1:0:0:0:0:0 -> PS, 375.648620583
# 0:1:0:1:1:1:0:1 -> WE, 320.037996657
# 1:1:0:0:0:1:0:1 -> PS, 410.042397188
# 1:1:0:1:0:1:1:0 -> PS, 397.232434409
# 1:1:0:1:0:1:1:1 -> PS, 474.581761618
# 1:1:1:1:1:1:0:1 -> PS, 322.644915992
# 1:0:0:0:1:1:0:0 -> WE, 354.457572707
# 0:1:1:0:1:0:0:1 -> PS, 333.524363479
# 0:1:1:1:0:0:0:0 -> WE, 281.409430848
# 0:1:1:1:0:0:0:1 -> WE, 307.272125115
# 0:0:1:0:0:0:1:1 -> PS, 379.344989984
# 0:0:1:0:0:0:1:0 -> PS, 285.503629778
# 0:0:1:0:1:0:1:0 -> WE, 316.005661291
# 1:0:0:1:0:1:1:0 -> PS, 451.861994535
# 1:1:0:0:1:0:0:0 -> PS, 190.904478465
# 1:1:0:0:1:0:0:1 -> WE, 237.921945599
# 0:0:1:0:1:1:0:0 -> PS, 393.842377807
# 1:1:1:0:1:1:1:0 -> PS, 263.771794927
# 0:0:0:0:0:1:0:1 -> PS, 288.06947183
# 0:1:0:0:0:1:0:1 -> WE, 272.966878368
# 0:1:1:1:1:1:0:0 -> PS, 347.802891157
# 0:1:1:1:1:1:0:1 -> PS, 374.324452309
# 0:0:1:0:1:1:1:1 -> PS, 275.423155046
# 0:0:1:0:1:1:1:0 -> PS, 310.52818599
# 0:1:1:1:0:1:1:0 -> WE, 354.457572707
# 0:0:1:0:1:0:0:0 -> PS, 386.420757633
# 0:0:1:0:1:0:1:1 -> PS, 308.634243834
# 0:1:1:0:1:0:1:1 -> PS, 174.090220585
# 1:1:0:1:0:0:0:0 -> PS, 271.701787754
# 1:0:0:0:0:1:0:0 -> PS, 448.785131932
# 1:1:0:1:0:0:1:0 -> PS, 336.001661826
# 0:0:1:1:0:0:1:1 -> PS, 396.891404432
# 0:0:1:0:1:1:0:1 -> PS, 466.946435321
# 1:0:0:0:1:1:1:0 -> PS, 266.024846017
# 0:1:0:0:1:0:0:1 -> WE, 264.358178997
# 0:1:0:0:1:0:0:0 -> PS, 292.44252042
# 1:0:0:1:0:1:0:0 -> PS, 355.791882274
# 0:1:0:1:0:1:0:0 -> PS, 352.72246327
# 0:1:0:1:0:1:0:1 -> WE, 341.293890219
# 1:1:0:1:0:0:0:1 -> PS, 436.192171001
# 0:0:0:0:0:0:1:0 -> WE, 347.77811971
# 0:1:0:0:0:1:1:1 -> WE, 316.399558074
# 0:0:1:0:0:1:1:0 -> PS, 301.166793309
# 1:1:0:0:0:1:0:0 -> PS, 542.691445208
# 0:1:0:1:1:1:0:0 -> PS, 323.070142438
# 1:0:0:1:1:0:1:1 -> WE, 303.29700029
# 0:1:1:1:1:0:1:0 -> PS, 264.393682337
# 1:1:0:1:1:1:1:1 -> WE, 354.457572707
# 1:0:0:1:0:0:0:0 -> PS, 402.376547609
# 1:1:0:1:1:0:1:1 -> WE, 294.158998364
# 1:0:1:1:0:1:0:1 -> PS, 419.597958235
# 0:0:0:0:1:1:1:0 -> WE, 351.117846208
# 0:0:1:1:0:1:1:1 -> PS, 313.255209632
# 1:1:1:0:0:0:1:0 -> PS, 631.607514634
# 1:0:0:1:0:0:1:1 -> PS, 428.777523849
# 0:0:1:1:1:1:0:1 -> PS, 421.688642067
# 0:1:0:1:1:1:1:1 -> WE, 302.658838963
# 0:0:0:1:1:0:0:1 -> WE, 297.08352578
# 1:0:0:1:1:0:1:0 -> WE, 354.457572707
# 1:1:1:1:1:1:1:0 -> WE, 285.020996439
# 1:1:1:1:1:1:1:1 -> WE, 293.116079599
# 0:1:1:0:1:1:0:0 -> PS, 338.950962097
# 1:1:0:0:1:1:0:0 -> WE, 372.651416015
# 1:1:0:1:1:0:1:0 -> WE, 347.77811971
# 1:1:1:0:0:1:1:1 -> PS, 666.032633103
# 1:0:0:0:1:0:0:1 -> WE, 293.080254025
# 0:1:1:0:0:1:1:1 -> PS, 334.509405162
# 0:0:0:1:1:1:1:0 -> WE, 285.020996439
# 0:1:0:0:0:1:0:0 -> PS, 298.472151492
# 0:0:1:0:0:0:0:0 -> PS, 347.978386132
# 0:0:1:0:0:0:0:1 -> WE, 314.169722737
# 0:1:1:1:1:0:0:0 -> PS, 301.891442115
# 0:0:0:1:1:0:1:0 -> WE, 285.020996439
# 0:0:0:1:1:0:0:0 -> PS, 285.290850095
# 0:1:0:0:0:1:1:0 -> PS, 295.765388276
# 0:0:0:0:0:0:1:1 -> WE, 351.117846208
# 0:0:1:1:1:0:1:1 -> PS, 356.9673539
# 0:0:0:0:1:1:1:1 -> PS, 266.300865382
# 0:1:1:1:1:0:0:1 -> PS, 350.213217178
# 1:0:1:0:0:1:1:1 -> PS, 724.054718677
# 0:1:0:0:1:1:0:0 -> PS, 414.057854188
# 1:0:1:1:0:0:1:0 -> PS, 724.054718677
# 1:0:1:0:0:1:1:0 -> PS, 579.389993245
# 0:1:0:1:1:0:1:1 -> WE, 283.96856299
# 1:0:1:0:0:0:0:0 -> PS, 456.59254741
# 1:1:0:1:1:1:0:0 -> WE, 290.762637914
# 0:0:0:0:1:0:0:0 -> PS, 316.690475379
# 1:1:0:0:0:0:0:0 -> PS, 511.257954024
# 0:0:1:1:1:1:1:0 -> PS, 292.920187731
# 0:0:1:0:0:1:1:1 -> PS, 328.959293935
# 1:0:0:0:0:1:1:0 -> PS, 464.23813177
# 1:0:0:0:0:1:1:1 -> PS, 452.740161059
# 0:0:1:1:1:0:0:0 -> PS, 333.590788997
# 0:0:1:1:1:0:1:0 -> PS, 307.89161504
# 1:0:1:0:0:0:0:1 -> PS, 447.085783381
# 0:1:0:0:0:0:0:0 -> PS, 323.659926094
# 0:1:0:1:1:0:1:0 -> WE, 299.0104521
# 1:0:1:1:0:1:1:0 -> WE, 291.112997723
# 1:0:1:1:0:1:0:0 -> PS, 342.760447913
# 0:0:0:1:0:0:1:1 -> PS, 455.841327351
# 0:0:1:0:0:1:0:1 -> WE, 303.29700029
# 0:0:1:0:1:0:0:1 -> PS, 426.597760353
# 1:0:1:1:0:0:0:0 -> PS, 575.977084654
# 0:1:0:0:1:0:1:1 -> PS, 193.433948754
# 0:0:0:1:0:0:1:0 -> WE, 318.069421324
# 0:1:0:1:0:0:1:0 -> WE, 293.986299763
# 0:1:0:1:0:0:1:1 -> PS, 336.843956194
# 1:1:1:1:1:0:1:1 -> WE, 288.066997081
# 1:1:0:0:0:0:0:1 -> PS, 482.161144267
# 0:0:1:1:1:0:0:1 -> PS, 387.756691069
# 1:0:0:1:0:1:1:1 -> PS, 540.265580649
# 0:0:0:0:1:0:0:1 -> WE, 280.760115419
# 0:1:1:0:1:1:1:1 -> PS, 292.632658771
# 1:0:1:1:0:1:1:1 -> PS, 475.491741507
# 0:0:0:1:0:0:0:0 -> PS, 518.378541354
# 0:1:1:0:1:1:0:1 -> PS, 427.123175832
# 1:0:1:0:0:1:0:1 -> PS, 427.37000929
# 0:0:0:1:0:0:0:1 -> PS, 377.282161905
# 1:0:0:0:0:0:1:1 -> PS, 498.289254677
# 1:0:0:0:0:0:1:0 -> PS, 445.272572139
# 1:0:1:0:1:0:0:0 -> WE, 347.77811971
# 1:1:1:0:1:0:1:0 -> PS, 299.162564751
# 1:1:1:1:0:1:1:1 -> PS, 547.819762695
# 1:1:1:1:0:1:1:0 -> PS, 615.353465846
# 1:1:1:1:0:0:0:1 -> PS, 465.200865561
# 1:1:1:1:0:0:0:0 -> PS, 391.041971677
# 1:1:1:0:0:1:1:0 -> PS, 605.824344375
# 0:0:1:1:1:1:1:1 -> PS, 348.291711073
# 0:0:0:1:1:1:0:0 -> WE, 284.03421192
# 1:0:1:1:1:1:1:1 -> WE, 303.29700029
# 0:1:1:0:1:1:1:0 -> PS, 298.087100824
# 0:0:0:0:1:0:1:0 -> WE, 243.63294872
# 0:0:1:1:0:1:1:0 -> WE, 332.74547226
# 0:0:1:1:0:1:0:1 -> WE, 354.457572707
# 1:1:1:0:1:0:1:1 -> WE, 285.020996439
# 0:0:1:1:0:0:0:1 -> PS, 323.801239967
# 1:0:1:0:1:0:0:1 -> WE, 387.354353722
# 1:1:1:0:1:0:0:1 -> WE, 305.055338808
# 1:1:0:1:1:0:0:1 -> WE, 291.391908558
# 1:1:0:0:1:1:1:0 -> PS, 348.618551927
# 0:0:1:1:0:0:0:0 -> PS, 311.756781555
# 0:0:0:0:0:0:0:0 -> PS, 323.157703121
# 1:0:0:1:1:0:0:1 -> WE, 316.399558074
# 0:0:0:0:0:1:1:1 -> WE, 352.231088375
# 0:1:1:0:0:1:0:0 -> PS, 319.419888281
# 0:1:1:1:1:0:1:1 -> WE, 286.90351143
# 1:0:1:0:0:1:0:0 -> PS, 461.924790971
# 1:0:1:1:0:0:0:1 -> PS, 507.929590067
# 0:1:0:1:1:0:0:0 -> WE, 269.10894652
# 1:0:1:0:0:0:1:1 -> PS, 576.953924658
# 0:0:0:0:1:0:1:1 -> WE, 354.457572707
# 1:1:0:0:0:0:1:1 -> PS, 402.376547609
# 0:1:0:0:1:0:1:0 -> PS, 173.858424875
# 1:1:0:0:0:1:1:0 -> PS, 382.463374955
# 0:1:0:0:0:0:1:1 -> WE, 285.020996439
# 0:0:0:0:0:1:1:0 -> WE, 353.795912682
# 0:1:1:0:0:0:1:0 -> PS, 243.138124605
# 0:0:0:1:0:1:0:0 -> PS, 346.63245014
# 0:1:0:0:1:1:0:1 -> WE, 246.809326653
# 1:1:0:1:1:1:0:1 -> WE, 303.29700029
# 1:0:0:0:1:1:1:1 -> WE, 285.020996439
# 1:0:0:1:1:1:0:1 -> WE, 285.020996439
# 1:0:0:0:0:0:0:0 -> PS, 455.655744428
# 1:1:1:1:1:0:0:1 -> WE, 306.778433869
# 1:0:0:0:0:0:0:1 -> PS, 804.506389666
# 0:1:1:0:0:0:0:1 -> WE, 302.915461012
# 0:1:0:1:0:1:1:0 -> WE, 334.876557064
# 0:1:0:1:1:1:1:0 -> WE, 347.77811971
# 1:0:1:1:1:1:0:1 -> PS, 299.391998279
# 0:0:0:0:1:1:0:1 -> WE, 279.474808945
# 0:0:0:0:1:1:0:0 -> PS, 336.997201398
# 1:1:1:0:0:0:0:1 -> PS, 552.894507933
# 0:0:1:1:1:1:0:0 -> PS, 338.268220386
# 1:1:1:1:0:1:0:0 -> PS, 428.131982336
# 1:1:1:1:0:1:0:1 -> PS, 494.479900472
# 1:0:0:1:0:0:0:1 -> PS, 405.626282828
# 1:1:1:1:0:0:1:0 -> PS, 455.553512419
# 1:1:1:1:0:0:1:1 -> PS, 565.88327277
# 0:0:0:0:0:1:0:0 -> WE, 317.493786249
# 1:1:0:1:1:0:0:0 -> PS, 258.212740671
# 0:1:1:1:0:0:1:1 -> WE, 351.117846208
# 0:1:1:1:0:0:1:0 -> PS, 270.020056991
# 1:0:1:1:0:0:1:1 -> PS, 548.959226769
# 1:0:0:1:1:1:0:0 -> PS, 403.759313982
# 1:0:1:1:1:0:0:1 -> PS, 263.771794927
# 0:1:0:0:1:1:1:1 -> PS, 267.795161431
# 0:1:0:0:0:0:0:1 -> PS, 271.709106903
# 1:0:0:1:0:0:1:0 -> PS, 435.722019498
# 0:1:0:0:1:1:1:0 -> WE, 303.29700029
# 0:0:1:1:0:0:1:0 -> PS, 277.315656377
# 0:0:0:1:0:1:1:0 -> WE, 345.593080333
# 1:1:0:1:0:1:0:1 -> PS, 400.254606242
# 0:0:0:1:0:1:1:1 -> PS, 378.048979723
# 0:1:0:1:0:0:0:0 -> PS, 343.246938006
# 0:1:1:1:1:1:1:1 -> WE, 286.281959503
# 0:1:1:1:1:1:1:0 -> PS, 274.233175353
# 0:0:0:1:1:1:1:1 -> WE, 303.29700029
# 0:1:0:1:0:0:0:1 -> WE, 301.899482737
# 0:1:1:0:0:1:1:0 -> PS, 276.817020465
# 0:1:1:1:0:1:0:1 -> PS, 326.794986348
# 0:1:1:1:0:1:0:0 -> WE, 354.457572707
# 0:0:0:1:1:1:0:1 -> WE, 341.979971628
# 0:1:1:0:0:0:0:0 -> WE, 327.48617752
# 1:1:1:1:1:0:1:0 -> WE, 285.020996439
# 1:1:0:1:0:1:0:0 -> WE, 354.457572707
# 1:1:0:1:0:0:1:1 -> PS, 444.81541579
# 1:0:0:0:1:0:0:0 -> WE, 351.117846208
# 0:1:1:0:0:1:0:1 -> PS, 307.164087505
# 0:1:1:1:0:1:1:1 -> WE, 332.271450671
# 1:0:1:0:1:0:1:0 -> WE, 285.020996439
# 1:1:1:0:0:1:0:1 -> PS, 465.916483272
# 0:1:0:1:0:1:1:1 -> WE, 324.051351712
# 0:1:1:0:1:0:1:0 -> PS, 238.498916044
# 0:1:1:0:0:0:1:1 -> PS, 174.090220585
# 0:0:0:0:0:0:0:1 -> WE, 301.285887641
# 0:0:0:1:0:1:0:1 -> WE, 341.667429603
# 1:1:1:0:0:0:1:1 -> PS, 724.054718677
# 1:0:1:1:1:1:0:0 -> WE, 354.457572707
# 0:0:1:1:0:1:0:0 -> WE, 288.572788534
# 0:0:1:0:0:1:0:0 -> PS, 316.188189313
# 1:0:1:1:1:1:1:0 -> WE, 285.020996439
# 1:0:1:0:0:0:1:0 -> PS, 657.758244886
# 0:1:0:1:1:0:0:1 -> WE, 301.430646834
# ECR value: 352.596993622
# 352.59699362154498

# %%
print "* Optimal feature set:\n["+', '.join(optimal_feature_set)+']'
# Out:
# * Optimal feature set:
# [difficultProblemCountSolved, cumul_MorphCount, CurrPro_avgProbTimeDeviationPS, cumul_FDActionCount, ruleScoreEQUIV, cumul_TotalWETime, cumul_symbolicRepresentationCount, cumul_AppRatio]

# %%
print "* Time cost in feature selection: "+str(time_cost)+' seconds'
# Out:
# * Time cost in feature selection: 12339.9450691 seconds
